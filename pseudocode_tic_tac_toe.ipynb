# %% [markdown]
# # step 1: create a grit variable

# %%
grit = [["", "", ""], ["", "", ""], ["", "", ""]]
# how to make it visible?

# %% [markdown]
# # step 2: create 2 players variables

# %%
player1, player2 = "x", "o"

# %% [markdown]
# # ask for input from player1

# %%
#turn_player1 = input(f" it's your turn {player1}, please choose a location so: first the line number, then space, then the column")

# %% [markdown]
# # adjust the grit according to the input from player1
# input are always strings, so first the input, change it to 2 integeres and store them in a new list

# %%
turn_player1 = "1 3"
print (turn_player1.split())
#adjusted_input = int(turn_player1)
