# %% [markdown]
# step 1: create a grit variable

# %%
grit = [["-", "-", "-"], ["-", "-", "-"], ["-", "-", "-"]]
# how to make it visible?

# %% [markdown]
# step 2: create 2 players variables
# assuming we always start with player 1, set player1 to True

# %%
player1, player2 = True, False

# %% [markdown]
# ask for input from player1

# %%
if player1:
    input(f" it's your turn x player, please choose a location so: first the line number, then space, then the column")
else:
    input(f" it's your turn o player, please choose a location so: first the line number, then space, then the column")

# %% [markdown]
# take the input and adjust it to our grit
# input are always strings, so first the input, change it to 2 integeres and substract 1 to adjust it to list indices

# %%
turn_player1 = "1 3"
turn_list = turn_player1.split()
input_line = int(turn_list[0])-1
input_column = int(turn_list[1])-1
#turn_list = [input_line-1, input_column-1]
print (input_line, input_column)
# Out:
# 0 2

# %% [markdown]
# adjust the grit according to the input from player1

# %%
if player1 == True:
    grit[input_line][input_column] = "x"

print (grit)
# Out:
# [['', '', 'x'], ['', '', ''], ['', '', '']]

# %% [markdown]
# check if theres a win by doing the following this code:

# %% [markdown]
#  if theres no win, inform player1 they didnt win and that their turn is done, switch to player 2:

# %%
input("Press ENTER to switch to the other player")

if player1 == True:
    player1 = False
    player2 = True
else: 
    player1 = True
    player2 = False

# %% [markdown]
# repeat the same process with player2, player1 is set to False, inserting the grid "0" instead of "x"
